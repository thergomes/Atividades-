# %% [markdown]
# <a href="https://colab.research.google.com/github/thergomes/BCC-19-Esther-de-Oliveira-Gomes/blob/main/Tarefa9EstherdeOliveiraGomesipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Esther de Oliveira Gomes

# %%
#Exercicio1
#Faça um gráfico da taxa de analfabetismo em São Paulo em função do tempo (anos).

import pandas as pd
import matplotlib.pyplot as plt
Analfabetismo = pd.read_csv('https://raw.githubusercontent.com/BMClab/BasesComputacionais/master/dados/analfabetismo.csv')

plt.figure()
plt.plot(Analfabetismo ['Ano'], Analfabetismo['São Paulo'])
plt.grid()
plt.xlabel('Ano')
plt.ylabel('São Paulo')
plt.show()
